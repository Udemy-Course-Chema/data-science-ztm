# %% [markdown]
# # Manipulating Data Part 3

# %%
import pandas as pd 
from pandas import Series,DataFrame

# %%
df_cars_sales = pd.read_csv('./../DataFrames/car-sales.csv')

# %%
df_cars_missing_data = pd.read_csv('./../DataFrames/car-sales-missing-data.csv')

# %%
seats_column = Series([5,5,5,5,5])
df_cars_sales['Seats'] = seats_column

# %%
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
df_cars_sales.fillna(5, inplace=True)

# %%
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
fuel_economy = [7.5,9.2, 5.0, 9.6, 8.7,4.7,7.6, 8.7, 3.0, 4.5]
df_cars_sales['Fuel per 100KM'] = fuel_economy

# %%
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5

# %%
df_cars_sales['Total fuel used (L)'] = df_cars_sales['Odometer (KM)'] / 100 * df_cars_sales['Fuel per 100KM']

# %%
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Total fuel used (L)
# 0            11253.225
# 1             8086.708
# 2             1627.450
# 3             1073.184
# 4            18539.265
# ...

# %%
df_cars_sales['Number of Wheels'] = 4

# %%
df_cars_sales['Passed Road Saftery'] = True

# %%
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftery
# 0            11253.225                 4                 True
# ...

# %%
df_cars_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftery
# 2             1627.450                 4                 True
# ...

# %%
cars_sales_shuffled = df_cars_sales.sample(frac=1)
cars_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftery
# 0            11253.225                 4                 True
# ...

# %% [markdown]
# ## .sample(frac)
#
# Where frac is the fraction of that sample
#
# .5 is 50%
#
# 1 is 100%
#
# Español: Significa una muestra, para hacer los experimentos en el Machine Learning como si fuera en la clase de química.
#
# **Utiliza esta función por si viene millones de rows. Si no usas, se traba el laptop**

# %% [markdown]
# * Only select 20% of data.
#
# Only apply to 1 million rows of data.
#
# * Select 1% of data (0.01)
#
# Only apply to 2 million rows of data. ( 0.01 )

# %%
cars_sales_shuffled.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftery
# 0            11253.225                 4                 True
# 5             4663.011                 4                 True
# 4            18539.265                 4                 True
# 3             1073.184                 4                 True
# 2             1627.450                 4                 True

# %% [markdown]
# ### Reset Index

# %%
cars_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftery
# 6             3473.048                 4                 True
# ...

# %%
cars_sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price  Seats  \
# 0      0  Toyota  White         150043      4   $4,000.00    5.0
# 1      6   Honda   Blue          45698      4   $7,500.00    5.0
# 2      8  Toyota  White          60000      4   $6,250.00    5.0
# 3      1   Honda    Red          87899      4   $5,000.00    5.0
# 4      3     BMW  Black          11179      5  $22,000.00    5.0
# 5      2  Toyota   Blue          32549      3   $7,000.00    5.0
# 6      7   Honda   Blue          54738      4   $7,000.00    5.0
# 7      4  Nissan  White         213095      4   $3,500.00    5.0
# 8      9  Nissan  White          31600      4   $9,700.00    5.0
# 9      5  Toyota  Green          99213      4   $4,500.00    5.0
#
#    Fuel per 100KM  Total fuel used (L)  Number of Wheels  Passed Road Saftery
# 0             7.5            11253.225                 4                 True
# 1             7.6             3473.048                 4                 True
# ...

# %%
cars_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftery
# 0            11253.225                 4                 True
# ...

# %%
 # cars_sales_shuffled.drop('index', axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 1  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 2   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 3  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 4  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 5     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 6  Toyota  Green          99213      4   $4,500.00    5.0             4.7
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  Nissan  White          31600      4   $9,700.00    5.0             4.5
# 9  Nissan  White         213095      4   $3,500.00    5.0             8.7
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftery
# 0             3473.048                 4                 True
# ...

# %%
cars_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
cars_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 2  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 3   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 4     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 5  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 6   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 7  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 8  Nissan  White          31600      4   $9,700.00    5.0             4.5
# 9  Toyota  Green          99213      4   $4,500.00    5.0             4.7
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftery
# 0            11253.225                 4                 True
# ...

# %%
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   Honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   Honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  Toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  Nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftery
# 0            11253.225                 4                 True
# ...

# %% [markdown]
# ## .apply()
#
# In Odometer (KM)'s column, we want to convert Odometer to Miles

# %%
df_cars_sales['Odometer (KM)'] = df_cars_sales['Odometer (KM)'].apply( lambda x: x / 1.6)

# %%
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White      93776.875      4   $4,000.00    5.0             7.5
# 1   Honda    Red      54936.875      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue      20343.125      3   $7,000.00    5.0             5.0
# 3     BMW  Black       6986.875      5  $22,000.00    5.0             9.6
# 4  Nissan  White     133184.375      4   $3,500.00    5.0             8.7
# 5  Toyota  Green      62008.125      4   $4,500.00    5.0             4.7
# 6   Honda   Blue      28561.250      4   $7,500.00    5.0             7.6
# 7   Honda   Blue      34211.250      4   $7,000.00    5.0             8.7
# 8  Toyota  White      37500.000      4   $6,250.00    5.0             3.0
# 9  Nissan  White      19750.000      4   $9,700.00    5.0             4.5
#
#    Total fuel used (L)  Number of Wheels  Passed Road Saftery
# 0            11253.225                 4                 True
# ...
