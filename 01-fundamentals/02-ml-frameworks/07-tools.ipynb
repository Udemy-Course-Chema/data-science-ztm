# %% [markdown]
# # Tools

# %% [markdown]
# 1. Computer
# 2. Anaconda
#     1. And his libraries(Pandas, jupyter Notebook, NumPy, scikit-learn, tensorflow)

# %% [markdown]
# ![image.png](attachment:image.png)
