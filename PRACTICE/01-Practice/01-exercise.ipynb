# %% [markdown]
# # 01 - Exercise

# %%
# 1. import pandas
import pandas as pd
from pandas import Series, DataFrame

# %%
# 6. Load CSV 
df_cars_sales = pd.read_csv('./../../01-fundamentals/DataFrames/car-sales.csv')

# %%
# 2. Create a Series of three different colors. 
series_colors = Series(["Black",'Yellow','Pink'])

# %%
# 3. View the series of different colors.
series_colors
# Out:
# 0     Black
# 1    Yellow
# 2      Pink
# dtype: object

# %%
# 4. Create a series of three different car types and view it
series_car_types = Series(['Bus','Deportive','Normal'])
series_car_types
# Out:
# 0          Bus
# 1    Deportive
# 2       Normal
# dtype: object

# %%
# 5. Combine the series of cars and colors into a DataFrame
df_cars = DataFrame({'Colors': series_colors,'Type': series_car_types})
df_cars
# Out:
#    Colors       Type
# 0   Black        Bus
# 1  Yellow  Deportive
# 2    Pink     Normal

# %%
# 7. Export the dataframe to CSV 
df_cars.to_csv('./the_cars_data.csv')

# %%
# 8. Find the different datatypes of the car data DataFrame 
df_cars.dtypes
# Out:
# Colors    object
# Type      object
# dtype: object

# %%
# 9. Describe your current car sales DataFrame using Describe()
df_cars_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# 10. Get information about you DataFrame using info
df_cars_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %% [markdown]
# Describe that the data has not null and there are two types: object and int64.

# %%
# 11. Create a Series of different numbers and find the mean of them 
series_numbers = Series([5,34,654,23,65,32])
series_numbers
# Out:
# 0      5
# 1     34
# 2    654
# 3     23
# 4     65
# 5     32
# dtype: int64

# %%
series_numbers.mean()
# Out:
# 135.5

# %%
# 12 Create a Series of different numbers and find the sum of them. 
series_add_numbers = Series([445,65,34,23,125,56])
series_add_numbers
# Out:
# 0    445
# 1     65
# 2     34
# 3     23
# 4    125
# 5     56
# dtype: int64

# %%
series_add_numbers.sum()
# Out:
# 748

# %%
# 13. List out all the column names of the car sales DataFrame
df_cars_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# 14. Find the length of the car sales DataFrame 
len(df_cars_sales)
# Out:
# 10

# %%
# 15. Show the first 5 rows of the car sales DataFrame 
df_cars_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# 16. Show the first 7 rows of the car sales dataFrame 
df_cars_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# 17. Show the bottom 5 rows of the car sales DataFrame 
df_cars_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# 18. Use .loc to select the row at index 3 of the car sales DataFrame 
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df_cars_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# 19. Use .iloc to select the row at position 3 of the car sales DataFrame 
df_cars_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# Why they are the same?
#
# Because nothing altered the table. It is the same table as you see.

# %%
# 20. Select the "odometer (KM )" column from the car sales DF
df_cars_sales['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# 21. Find the mean of the 'Odometer (KM)' column in the car sales DataFrame 
df_cars_sales['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
# 22. Select the rows with over 100,000 kilometers on the Odometer 
df_cars_sales[ df_cars_sales['Odometer (KM)'] > 100000 ]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# 23. Create a crosstab of the "MaKe" and "Doors" columns
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab( df_cars_sales['Make'], df_cars_sales['Odometer (KM)'])
# Out:
# Odometer (KM)  11179   31600   32549   45698   54738   60000   87899   99213   \
# Make
# BMW                 1       0       0       0       0       0       0       0
# Honda               0       0       0       1       1       0       1       0
# Nissan              0       1       0       0       0       0       0       0
# Toyota              0       0       1       0       0       1       0       1
#
# Odometer (KM)  150043  213095
# Make
# BMW                 0       0
# Honda               0       0
# Nissan              0       1
# Toyota              1       0

# %%
# 24. Group columns of the car sales DataFrame by the "Make" column and find the average
df_cars_sales.groupby(['Make']).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# 25. Import matplotlib and create a plot of the Odometer column, and use 
# %matplotlib inline
import matplotlib

# %%
# %matplotlib inline

# %%
# 26. Create a histogram of the Odometer column using hist()
df_cars_sales['Odometer (KM)'].hist()
# Out:
# <Axes: >

# %%
# 27. Try to plot the price column using plot()
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df_cars_sales['Price'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df_cars_sales['Price'].plot()
#
# File ~/anaconda3/envs/DataScienceByZeroToMaster/lib/python3.11/site-packages/pandas/plotting/_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/anaconda3/envs/DataScienceByZeroToMaster/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %% [markdown]
# Didn't work because is string type.

# %%
# 28. Remove the puntuaction from Price column 
# df_cars_sales['Price'] = df_cars_sales['Price'].str.replace('[\$\,\.]','', regex=True)
df_cars_sales['Price'] = df_cars_sales['Price'].astype(str).str.replace('[\$\]','', regex=True)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[95], line 3
#       1 # 28. Remove the puntuaction from Price column
#       2 # df_cars_sales['Price'] = df_cars_sales['Price'].str.replace('[\$\,\.]','', regex=True)
# ----> 3 df_cars_sales['Price'] = df_cars_sales['Price'].astype(str).str.replace('[\$\]','', regex=True)
#
# File ~/anaconda3/envs/DataScienceByZeroToMaster/lib/python3.11/site-packages/pandas/core/strings/accessor.py:129, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     124     msg = (
#     125         f"Cannot use .str.{func_name} with values of "
#     126         f"inferred dtype '{self._inferred_dtype}'."
#     127     )
#     128     raise TypeError(msg)
# --> 129 return func(self, *args, **kwargs)
#
# ...

# %%
# 29. Check the changes to the price column
df_cars_sales['Price']
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %%
# 30. Remove the 2 extras zeros at the end of the price column
df_cars_sales['Price'] = df_cars_sales['Price'].str[:-2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 2
#       1 # 30. Remove the 2 extras zeros at the end of the price column
# ----> 2 df_cars_sales['Price'] = df_cars_sales['Price'].str[:-2]
#
# File ~/anaconda3/envs/DataScienceByZeroToMaster/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~/anaconda3/envs/DataScienceByZeroToMaster/lib/python3.11/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
# ...

# %%
# 31- Check the changes to the price column
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# 32. Change the datatype of the price column to integers
df_cars_sales['Price'] = df_cars_sales['Price'].astype(int)

# %%
df_cars_sales['Price']
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int64

# %%
# 33. Lower the strings of the Make columns 
df_cars_sales['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
df_cars_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
# 34. Make lowering the case of the Make column permanent. 
df_cars_sales['Make'] = df_cars_sales['Make'].str.lower()

# %%
# 35. Check the car sales Dataframe 
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
# 36. Import the car sales DataFrame with missing data. And check out. 
df_cars_sales_missing_data = pd.read_csv('./../../01-fundamentals/DataFrames/car-sales-missing-data.csv')
df_cars_sales_missing_data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# 37. Fill the Odometer column missing values with the mean of the column inplace
df_cars_sales_missing_data['Odometer'].fillna( df_cars_sales_missing_data['Odometer'].mean(), inplace=True )

# %%
# 38. View the car sales missing DataFrame and verify the changes. 
df_cars_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# 39. Remove the rest of the missing data inplace. 
df_cars_sales_missing_data.dropna(inplace=True)

# %%
# 40. Verify the missing values are removed by viewing the DataFrame
df_cars_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
# 41. Create a "Seats" column where EVERY ROW HAS A VALUE of 5. 
seats_column = 5
df_cars_sales_missing_data['Seats'] = seats_column

# %%
# 42. Create a column called "Engine Size" with random values between 1.3 and 4.5. 
df_cars_sales_missing_data['Engine Size'] = [1.2, 1.5, 4.4, 4.5,3.4,2.2]

# %%
df_cars_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.2
# 1   Honda    Red   87899.000000    4.0   $5,000      5          1.5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          4.4
# 3     BMW  Black   11179.000000    5.0  $22,000      5          4.5
# 4  Nissan  White  213095.000000    4.0   $3,500      5          3.4
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          2.2

# %%
# 43. Create a column wich represent  the price of a car per kilometer, then view the DataFrame. 
df_cars_sales_missing_data['Price'] = df_cars_sales_missing_data['Price'].str.replace('[\$\,\,]','',regex=True)

# %%
df_cars_sales_missing_data['Price'] = df_cars_sales_missing_data['Price'].astype(int)

# %%
df_cars_sales_missing_data.dtypes
# Out:
# Make            object
# Colour          object
# Odometer       float64
# Doors          float64
# Price            int64
# Seats            int64
# Engine Size    float64
# dtype: object

# %%
df_cars_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   4000      5          1.2
# 1   Honda    Red   87899.000000    4.0   5000      5          1.5
# 2  Toyota   Blue   92302.666667    3.0   7000      5          4.4
# 3     BMW  Black   11179.000000    5.0  22000      5          4.5
# 4  Nissan  White  213095.000000    4.0   3500      5          3.4
# 5  Toyota  Green   92302.666667    4.0   4500      5          2.2

# %%
df_cars_sales_missing_data['Price Per Kilometer'] = df_cars_sales_missing_data['Odometer'] / df_cars_sales_missing_data['Price']
df_cars_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size  \
# 0  Toyota  White  150043.000000    4.0   4000      5          1.2
# 1   Honda    Red   87899.000000    4.0   5000      5          1.5
# 2  Toyota   Blue   92302.666667    3.0   7000      5          4.4
# 3     BMW  Black   11179.000000    5.0  22000      5          4.5
# 4  Nissan  White  213095.000000    4.0   3500      5          3.4
# 5  Toyota  Green   92302.666667    4.0   4500      5          2.2
#
#    Price Per Kilometer
# 0            37.510750
# 1            17.579800
# 2            13.186095
# 3             0.508136
# 4            60.884286
# 5            20.511704

# %%
# 44. Remove the last column you added using drop()
df_cars_sales_missing_data.drop('Price Per Kilometer', axis=1, inplace=True)

# %%
df_cars_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   4000      5          1.2
# 1   Honda    Red   87899.000000    4.0   5000      5          1.5
# 2  Toyota   Blue   92302.666667    3.0   7000      5          4.4
# 3     BMW  Black   11179.000000    5.0  22000      5          4.5
# 4  Nissan  White  213095.000000    4.0   3500      5          3.4
# 5  Toyota  Green   92302.666667    4.0   4500      5          2.2

# %%
# 45. Shuffle the DataFrame using sample() with the frac parameter set to 1. 
# And save the shuffled Dataframe to a new variable
cars_sales_shuffled = df_cars_sales.sample( frac = 1)
cars_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 9  Nissan  White          31600      4   $9,700.00
# 4  Nissan  White         213095      4   $3,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 6   Honda   Blue          45698      4   $7,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00

# %%
# 46. Reset the indexes of the shuffled DataFrame 
cars_sales_shuffled.reset_index( drop=True, inplace=True)
cars_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1     BMW  Black          11179      5  $22,000.00
# 2  Nissan  White          31600      4   $9,700.00
# 3  Nissan  White         213095      4   $3,500.00
# 4   Honda   Blue          54738      4   $7,000.00
# 5  Toyota  White          60000      4   $6,250.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7  Toyota  Green          99213      4   $4,500.00
# 8   Honda    Red          87899      4   $5,000.00
# 9  Toyota   Blue          32549      3   $7,000.00

# %%
# 47. Change the odometer values from kilometers to miles using a lambda function. 
# Then view the DataFrame 
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df_cars_sales['Odometer (KM)'] = df_cars_sales['Odometer (KM)'].apply( lambda x: x / 1.6 )
df_cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White      93776.875      4   $4,000.00
# 1   Honda    Red      54936.875      4   $5,000.00
# 2  Toyota   Blue      20343.125      3   $7,000.00
# 3     BMW  Black       6986.875      5  $22,000.00
# 4  Nissan  White     133184.375      4   $3,500.00
# 5  Toyota  Green      62008.125      4   $4,500.00
# 6   Honda   Blue      28561.250      4   $7,500.00
# 7   Honda   Blue      34211.250      4   $7,000.00
# 8  Toyota  White      37500.000      4   $6,250.00
# 9  Nissan  White      19750.000      4   $9,700.00

# %%
# 48. Changes the title of the Odometer (Km) to Represent miles instead of kilometers
df_cars_sales = df_cars_sales.rename( columns={ "Odometer (KM)" : "Represent Miles" })
df_cars_sales
# Out:
#      Make Colour  Represent Miles  Doors       Price
# 0  Toyota  White        93776.875      4   $4,000.00
# 1   Honda    Red        54936.875      4   $5,000.00
# 2  Toyota   Blue        20343.125      3   $7,000.00
# 3     BMW  Black         6986.875      5  $22,000.00
# 4  Nissan  White       133184.375      4   $3,500.00
# 5  Toyota  Green        62008.125      4   $4,500.00
# 6   Honda   Blue        28561.250      4   $7,500.00
# 7   Honda   Blue        34211.250      4   $7,000.00
# 8  Toyota  White        37500.000      4   $6,250.00
# 9  Nissan  White        19750.000      4   $9,700.00
